# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
book=pd.read_csv("Books.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
print(book.shape)
print(list(book.columns))
# Out:
# (271360, 8)
# ['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-S', 'Image-URL-M', 'Image-URL-L']

# %%
book.isna().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
book["Year-Of-Publication"].unique()
# Out:
# array([2002, 2001, 1991, 1999, 2000, 1993, 1996, 1988, 2004, 1998, 1994,
#        2003, 1997, 1983, 1979, 1995, 1982, 1985, 1992, 1986, 1978, 1980,
#        1952, 1987, 1990, 1981, 1989, 1984, 0, 1968, 1961, 1958, 1974,
#        1976, 1971, 1977, 1975, 1965, 1941, 1970, 1962, 1973, 1972, 1960,
#        1966, 1920, 1956, 1959, 1953, 1951, 1942, 1963, 1964, 1969, 1954,
#        1950, 1967, 2005, 1957, 1940, 1937, 1955, 1946, 1936, 1930, 2011,
#        1925, 1948, 1943, 1947, 1945, 1923, 2020, 1939, 1926, 1938, 2030,
#        1911, 1904, 1949, 1932, 1928, 1929, 1927, 1931, 1914, 2050, 1934,
#        1910, 1933, 1902, 1924, 1921, 1900, 2038, 2026, 1944, 1917, 1901,
#        2010, 1908, 1906, 1935, 1806, 2021, '2000', '1995', '1999', '2004',
#        '2003', '1990', '1994', '1986', '1989', '2002', '1981', '1993',
#        '1983', '1982', '1976', '1991', '1977', '1998', '1992', '1996',
#        '0', '1997', '2001', '1974', '1968', '1987', '1984', '1988',
#        '1963', '1956', '1970', '1985', '1978', '1973', '1980', '1979',
#        '1975', '1969', '1961', '1965', '1939', '1958', '1950', '1953',
#        '1966', '1971', '1959', '1972', '1955', '1957', '1945', '1960',
#        '1967', '1932', '1924', '1964', '2012', '1911', '1927', '1948',
#        '1962', '2006', '1952', '1940', '1951', '1931', '1954', '2005',
#        '1930', '1941', '1944', 'DK Publishing Inc', '1943', '1938',
#        '1900', '1942', '1923', '1920', '1933', 'Gallimard', '1909',
#        '1946', '2008', '1378', '2030', '1936', '1947', '2011', '2020',
#        '1919', '1949', '1922', '1897', '2024', '1376', '1926', '2037'],
#       dtype=object)

# %%
i=list(book["Publisher"])
j=list(book['Year-Of-Publication'])
r = {}
for key in i:
    for value in j:
        r[key] = value
        j.remove(value)
        break

# %%
r
# Out:
# {'Oxford University Press': 1996,
#  'HarperFlamingo Canada': 2001,
#  'HarperPerennial': '1991',
#  'Farrar Straus Giroux': 1999,
#  'W. W. Norton &amp; Company': 1998,
#  'Putnam Pub Group': 1998,
#  'Berkley Publishing Group': 1986,
#  'Audioworks': 2002,
#  'Random House': 2004,
#  'Scribner': 2002,
#  'Emblem Editions': 1997,
#  'Citadel Press': 2004,
#  'House of Anansi Press': '1992',
#  'Mira Books': 2003,
#  'Health Communications': 1998,
#  'Brilliance Audio - Trade': 1992,
#  'Kensington Publishing Corp.': 1998,
#  'River City Pub': 1994,
#  'Dell': 2001,
#  'Plume': 1993,
#  'Three Rivers Press': 2004,
#  'Ryland Peters &amp; Small Ltd': '2001',
#  'Cypress House': 2002,
#  'HarperEntertainment': 2003,
#  'Scholastic': 1992,
#  'Aladdin': 2002,
#  'Too Far': 2004,
#  'Ballantine Books': 1993,
#  'Random House Trade Paperbacks': 1989,
#  'LÃ?Â¼bbe': 2002,
#  'Goldmann': 2000,
#  'Alfred A. Knopf': 1987,
#  'Little Brown &amp; Company': '1974',
#  'Harpercollins': 1990,
#  'Avon': 2002,
#  'Bantam': 2003,
#  'Fireside': 1996,
#  'HarperTorch': 1999,
#  'Bantam Books': 1988,
#  'Pocket': 1982,
#  'Tor Books': 2003,
#  'Tyndale House Publishers': 1977,
#  'HarperCollins Publishers': 1990,
#  'Harvest Books': 2004,
#  'Chambers Harrap Publishers Ltd': '2000',
#  'Avon Books': 1984,
#  'Speed Graphics': 1993,
#  'Sunflower Press': 2002,
#  'Laurel Leaf': 1997,
#  'Gallimard': 1990,
#  'Prentice Hall (K-12)': 1994,
#  'NTC/Contemporary Publishing Company': 1999,
#  "St. Martin's Press": 1991,
#  '1stBooks Library': 2004,
#  'Avon Trade': 1999,
#  'Penguin Books': 1997,
#  'Signet Book': 1982,
#  'Thomas Nelson': 1970,
#  'Ace Books': 1982,
#  'Landoll': 1995,
#  'Knopf': 2002,
#  'Andrew Scott Publishers': 1999,
#  'Atlantic Monthly Press': 2001,
#  'Hodder &amp; Stoughton General Division': 1994,
#  'Simon &amp; Schuster (Trade Division)': 1999,
#  'Perennial': 1991,
#  'McGraw-Hill': 1981,
#  'Bantam Doubleday Dell': 1982,
#  'Little, Brown': 1999,
#  'Minotauro': '1995',
#  'Distribooks': 2001,
#  'Back Bay Books': 1982,
#  'Doubleday Books': 1996,
#  'Warner Books': 1991,
#  'Vintage': 1986,
#  'Hyperion': 0,
#  'Tusquets': 2002,
#  'Star Trek': 2002,
#  'Pocket Star': 2003,
#  'Tor Books (Mm)': 1993,
#  'Harper Mass Market Paperbacks (Mm)': 1993,
#  'Warner Books (Mm)': 1981,
#  'Onyx Books': 1991,
#  'Free Press': 1998,
#  'Thomas Nelson Inc': 1994,
#  'Edicoes Asa': 1998,
#  'Pan Macmillan': 2001,
#  'Anchor': 2002,
#  'W.W. Norton &amp; Company': 2000,
#  'Arcadia Books': 2000,
#  'John Hunt Publishing, Ltd.': '2003',
#  'Fawcett Books': 1988,
#  'Alianza': 1992,
#  'Downtown Book Center': 1996,
#  'Trafalgar Square': 0,
#  'Delta': 1998,
#  'Laure Leaf': '1995',
#  'Love Spell': 2000,
#  'Penguin Books Ltd': 1999,
#  'Roc': 2001,
#  'Tor Fantasy': 2001,
#  'Harpercollins Publisher': 0,
#  'Mariner Books': 1992,
#  'Picador (UK)': '1998',
#  'Dover Publications': 1977,
#  'Simon Pulse': 2004,
#  'Nelson Books': 2002,
#  'Regal Books': 1977,
#  'Del Rey Books': 1981,
#  'Spectra': 1990,
#  'Philipp Reclam, Jun Verlag GmbH': 0,
#  'Diogenes': '2003',
#  'Diogenes Verlag': 2003,
#  'Distribooks Inc': 2003,
#  'Deutscher Taschenbuch Verlag (DTV)': '0',
#  'Dtv': 1997,
#  'Droemersche Verlagsanstalt Th. Knaur Nachf., GmbH &amp; Co.': 2001,
#  'Heyne': 1993,
#  'Kiepenheuer &amp; Witsch': 1986,
#  'Piper': 2001,
#  'Rowohlt, Reinbek': '1997',
#  'Rowohlt Tb.': 1996,
#  'Suhrkamp': 1983,
#  'Ullstein Tb': 2000,
#  'Bertelsmann, MÃ?Â¼nchen': 2001,
#  'Fischer (Tb.), Frankfurt': 2003,
#  'St Martins Pr': 1987,
#  'Bantam Dell Pub Group': 1998,
#  'Doubleday': 1974,
#  'Delacorte Books for Young Readers': '1983',
#  'Island': '1999',
#  'Warner Vision': '1995',
#  'Plume Books': 1996,
#  'Jove Books': 1992,
#  'Atria': 1996,
#  'University of Nebraska Press': 1990,
#  'Ivy Books': 1979,
#  'Regan Books': 2004,
#  'Harcourt': 1994,
#  'Vintage Books USA': 1996,
#  'Dutton Books': 1991,
#  'Delta Systems': '1995',
#  'HarperCollins': 2004,
#  'HarperFestival': 2000,
#  'HarperPrism': 1997,
#  'HarperTempest': '1999',
#  "St. Martin's Griffin": 1982,
#  'Orb Books': 1995,
#  'Harlequin': 2000,
#  'Modern Library': 1992,
#  'Knopf Books for Young Readers': 2003,
#  'William Morrow': 1991,
#  'Wendy Lamb Books': '2003',
#  'Random House Inc': 1984,
#  'Push': 2004,
#  'Signet Classics': 1999,
#  'Signet': '2002',
#  'Faber Faber Inc': 0,
#  'Viking Juvenile': 2001,
#  'Simon &amp; Schuster': 1999,
#  'Touchstone': 1989,
#  'Egmont Childrens Books': 1995,
#  'Dreamhaven Books': 1993,
#  'DC Comics': 2003,
#  'Dark Horse Comics': 1998,
#  'Alpha Books': 1997,
#  'Farrar Straus &amp; Giroux': 1991,
#  'Dell Publishing Company': 1984,
#  'Riverhead Books': 2000,
#  'University of California Press': 2004,
#  'Spectra Books': 1992,
#  'Viking Books': 1999,
#  'Hackett Pub Co Inc': 2001,
#  'W W Norton &amp; Co': 1988,
#  'Washington Square Press': 1980,
#  'Scholastic Paperbacks (Mm)': 1988,
#  'Harpercollins Juvenile Books': 1981,
#  'Starfire': 1998,
#  'Last Knight Pub Co': 2002,
#  'Del Rey': 2004,
#  'Eos': 2004,
#  "St. Martin's Paperbacks": 1995,
#  'Columna': 1990,
#  "Viking Children's Books": 0,
#  'Delacorte Press': 2000,
#  "Reader's Digest": 1999,
#  'Editores Mexicanos Unidos, S.A.': 1998,
#  'Quill (HarperCollins)': '1998',
#  'Anagrama': 1996,
#  'Douglas Gibson Books': 2002,
#  'McClelland &amp; Stewart': 1988,
#  'Arcade Publishing': 1997,
#  'Fischer Taschenbuch Verlag GmbH': 1998,
#  'Access Press (HarperCollins)': '1992',
#  'John Wiley &amp; Sons Inc': 1991,
#  'Penguin USA (Paper)': '1999',
#  'Scribner Paper Fiction': 1993,
#  'Pocket Books': 1996,
#  'Readers Digest Assn': 1985,
#  'Broadway Books': 2002,
#  'F. H. Revell': '1978',
#  'Baker Book House': 1990,
#  'W Publishing Group': 1998,
#  'NavPress': '1980',
#  'Pub Group West': 1997,
#  'YWAM Publishing': 1999,
#  'F.J. Moody': 1997,
#  'Emmaus Road Intl': 1991,
#  'Puffin Books': 1996,
#  'Castle Books': '1982',
#  'Llewellyn Publications': 2003,
#  'Harper Collins - UK': '2000',
#  'Silhouette': 2000,
#  'Penguin USA': 1970,
#  'Fawcett': '1995',
#  'University Press of America': '1982',
#  'Globe Pequot Pr': 1994,
#  'New York Review of Books': 2002,
#  'Artisan Publishers': 1978,
#  'Amber-Allen Publishing': '2001',
#  'Plaza &amp; JanÃ©s': '1987',
#  'Destino': '1974',
#  'Lectorum Pubns (J)': 1984,
#  'Edicions 62': 1996,
#  'Editiones B, Grupo Zeta': 1991,
#  'Laia': 1988,
#  'Editorial Laia': 1980,
#  'Edicions de la Magrana': '1986',
#  'Editorial EmpÃºries': '1997',
#  'Area': 1987,
#  'Ediciones Temas de Hoy': '1992',
#  'Salamandra': '2004',
#  'Hal Leonard Corp': '1993',
#  'Ediciones B': 2002,
#  'Dial Books': 2002,
#  'Bantam Dell Publishing Group': '1986',
#  'Jump at the Sun': 1997,
#  'I Books': 2002,
#  'Wizards of the Coast': 1988,
#  'Cornell University Press': 1999,
#  'Troll Communications Llc': 1989,
#  'Price Stern Sloan': 1970,
#  'Playmore Inc. Publishers': '1990',
#  'National Geographic Society': 1975,
#  'Kidsbooks.Com': '1995',
#  'HarperTrophy': 1998,
#  'Soho Press': 2001,
#  'Nan A. Talese': 1991,
#  'Owl Books': 2004,
#  'Readers Digest': 1996,
#  'Simon Schuster Trade': '0',
#  'Image': 2001,
#  'Andrews McMeel Publishing': 2004,
#  'Houghton Mifflin Company': 1992,
#  'MacMillan Publishing Company.': 1996,
#  'Picador USA': 2003,
#  'Putnam Publishing Group': 1994,
#  'Random House Value Publishing': 1984,
#  'Villard Books': 1999,
#  'Morehouse Group': 1982,
#  'Ecco Press': 1990,
#  'Cowley Publications': '1994',
#  'White Pine Press (NY)': '1986',
#  'Fabbri - RCS Libri': '0',
#  'Edizioni E/O': 2002,
#  'Puffin': '2001',
#  'Harvard University Press': 1996,
#  'Saunders College Publishing': '1984',
#  'Houghton Mifflin': 1978,
#  'Schocken Books': 1982,
#  'Watson-Guptill Publications': 2002,
#  'Random House Canada': 1999,
#  'Thomas Dunne Books': 2002,
#  'Little Brown &amp; Co': 1990,
#  'Noble House': '2002',
#  'Atria Books': 2003,
#  'Winedale Publishing': 1999,
#  'Pinnacle Books': 1999,
#  'Grove Press': 2004,
#  'Editech Pr': 1990,
#  'WestBow Press': 1999,
#  'Henry Holt &amp; Company': 1995,
#  'Hyperion Books': 1994,
#  'Thorndike Pr': 1985,
#  'Zebra Books': 1999,
#  'Golden Books Publishing Company': 0,
#  'Yearling': 1978,
#  'Apple Signature (Scholastic)': '2001',
#  'Scholastic, Inc.': 1994,
#  'Golden Books': 1994,
#  'Crabtree Publishing Company': '1997',
#  'Inner Ocean Publishing': 2001,
#  "St. Martin's Minotaur": 2002,
#  'Scholastic Inc': 1987,
#  'Albert Whitman &amp; Company': 1995,
#  'Broadway': 2002,
#  'Childrens Press': '1974',
#  'Putnam Pub Group (Paper)': 1977,
#  'Griffin Trade Paperback': 1998,
#  'David R. Godine Publisher': 1986,
#  'New Directions Publishing Corporation': 1970,
#  'Jossey-Bass': 1996,
#  'Feltrinelli': 0,
#  'HarperSanFrancisco': 2004,
#  'Multnomah': 2000,
#  'Beacon Press': 1993,
#  'Harper Mass Market Paperbacks': 1990,
#  'MacAdam/Cage Publishing': 2003,
#  'LGF': 1998,
#  'Gallimard French': 0,
#  'Livre De Poche French': 0,
#  'Presses Pocket French': '0',
#  'Livre de Poche': 0,
#  "J'ai lu": 1999,
#  'Rowohlt': 1981,
#  'Lamuv': 1995,
#  'O. W. Barth Bei Scherz': '2000',
#  'Palgrave-Macmillan': '1982',
#  'Aufbau Taschenbuch Verlag': 1993,
#  'btb': '2001',
#  'Crown': 2003,
#  'William Morrow &amp; Company': 2002,
#  "Everyman's Library": 1992,
#  'Harmony': 2003,
#  'Sourcebooks Landmark': 2002,
#  'Little Brown and Company': 2001,
#  'Michael Joseph Ltd': '0',
#  'Seuil': 1991,
#  'Bloomsbury Pub Ltd': 2000,
#  'Penguin Putnam~trade': 1991,
#  'Lomond Books': '1995',
#  "Faber Children's Books": '2003',
#  'Abacus': 2000,
#  "Michael O'Mara Books": 1992,
#  'Trafalgar Square Books': 2000,
#  'Dargaud': '2002',
#  'Southwater Publishing': '2002',
#  'Brockhampton Press': '0',
#  "Union gÃ©nÃ©rale d'Ã©ditions": 1977,
#  'Canongate Books Ltd': '2003',
#  'Celestial Arts': 1999,
#  'Routledge': 2003,
#  'Bloomsbury Publishing PLC': '1995',
#  'Firebrand Books': 1989,
#  'Windstorm Creative': 2001,
#  'Akashic Books': '2004',
#  'New Amer Library': 1992,
#  'Alyson Books': 2001,
#  'Rising Tide Press (AZ)': 1995,
#  'Alyson Publications': 2000,
#  'Press Gang Publishers': 1994,
#  'Crimeline': 1995,
#  'Stonewall Inn Editions': 2001,
#  "Random House Children's Books": 1994,
#  'Miramax': 2003,
#  'Random House Childrens Books': 1986,
#  'Laurel-Leaf Books': 1978,
#  'Del Sol Press': 1991,
#  'Wings': '1994',
#  'Manning Publications': '2003',
#  'Ferguson Publishing Company': 1992,
#  'Einaudi': 1963,
#  'Ohio University Press': '1997',
#  'Hyperion Books for Children': 2000,
#  'Magic Carpet Books': '2003',
#  'Pleasant Company Publications': 2002,
#  'Scholastic Paperbacks': 2004,
#  'John F. Blair Publisher': 1985,
#  'Monarch Books': '2001',
#  'Flammarion': 1985,
#  'Phoenix Books': '0',
#  'Hyperion Press': 1999,
#  'Cambridge University Press': 1984,
#  'Amereon Limited': '1980',
#  'Hill &amp; Wang': 1996,
#  'Red Dress Ink': '2004',
#  'Anchor Pub': '2004',
#  'Four Walls Eight Windows': 2001,
#  'Steeple Hill': 1999,
#  'Ten Speed Pr': 1990,
#  'Reston Pub. Co': '1985',
#  'Word Publishing': 1989,
#  "G. P. Putnam's Sons": 2003,
#  'W. Morrow': '1974',
#  'Teamcom Books': 2000,
#  'Gulf Publishing Company': 1999,
#  'Dearborn Financial Publishing': '1998',
#  'Main Street Books': 1998,
#  'Random House, Inc.': 1992,
#  'Adams Media Corp': 1994,
#  'Mysterious Press': 1989,
#  'Mira': 1999,
#  'Harpercollins Library': 1970,
#  'Sagebrush Bound': 2003,
#  'W W Norton &amp; Co Inc': 1989,
#  'Picador': 2004,
#  'New English Library': '2000',
#  'Pearson Education': 1996,
#  'Diamond Books (NY)': 1991,
#  'Yearling Books': 1990,
#  'Forge Books': 2004,
#  'Pantheon Books': 1997,
#  'Infinity Publishing.com': '2003',
#  'Buy Books on the web.com': 2000,
#  'Infinity Publishing (PA)': '2003',
#  'Pantheon': 1981,
#  'Epicenter Press': '2003',
#  'Bantam Classics': 1986,
#  'Ravensburger Buchverlag Otto Maier GmbH': '0',
#  'Black Sparrow Books': 1982,
#  'Pages Publishing Group': 1990,
#  'Point Fantasy': '1999',
#  'AuthorsOmniscient Publishers': 2004,
#  'Random House Books for Young Readers': 2001,
#  'Chatto &amp; Windus': '1996',
#  'Hackett Publishing Company': 1999,
#  'Workman Pub. Co': '1975',
#  'Barnes Noble Books': 0,
#  'Houghton Mifflin Co': 2000,
#  'Natl Book Network': 1998,
#  'Harry N Abrams': 1995,
#  'Quest Books': 2000,
#  'The Lyons Press': 2003,
#  'Sterling Publishing': 1995,
#  'Shambhala': 1989,
#  'Hanser': '1977',
#  'Penguin Putnam~mass': 1983,
#  'Candlewick Press (MA)': 1993,
#  'Girl Press': 1997,
#  'Atheneum': 1998,
#  'MTV': 2001,
#  'Baldini&amp;Castoldi': 1999,
#  'Aufbau Tb': '2002',
#  'Deutscher Taschenbuch Verlag': 1983,
#  'Taschen Verlag': '1999',
#  'Berkley Pub Group': 1990,
#  'Forge': 1999,
#  'Bull Publishing Company': 1987,
#  "Fodor's": '2001',
#  'New Chapter Press': 1992,
#  'Smithmark Pub': 1991,
#  'Everyman Paperback Classics': '1993',
#  'Diogenes Verlag, ZÃ?Â¼rich': '1997',
#  'Faber &amp; Faber': 1988,
#  'British Film Institute': 1993,
#  'Zondervan': 1995,
#  'Zondervan Publishing Company': 2003,
#  'Harpercollins Uk': '0',
#  'Ecco': 2003,
#  'Pan': '1994',
#  'Beltz': 1995,
#  'Not Avail': 1981,
#  'Klett-Cotta': '2000',
#  'SauerlÃ?Â¤nder': '2001',
#  'Biting Dog Publications': 2003,
#  'Editions 10/18': 1977,
#  'Henry Holt &amp; Co': 1996,
#  'Penguin/Puffin Mass Market (Mm)': '1993',
#  'Workman Publishing': 2003,
#  'Marvel Books': 1993,
#  'Modern Publishing': '1988',
#  'Kriya Yoga Publications': 1998,
#  'Metropolitan Books': '2004',
#  'University of New Mexico Press': 1990,
#  'Elephant Paperbacks': 1990,
#  'Turner Pub': 1992,
#  'Daw Books': 1994,
#  'Distributors': 1992,
#  'Time Warner Books UK': 1997,
#  'Scholastic Press': '2004',
#  'Scholastic Point': 1998,
#  'The Medici Society Ltd': '0',
#  'Award Publications': 1999,
#  'Gollancz': 2000,
#  'WaterBrook Press': 2004,
#  'Moody Publishers': 1998,
#  'University of Toronto Press': 2002,
#  'Baen': 2002,
#  'UMP': 1969,
#  'H.J. Kramer': '1992',
#  'Speak': 1998,
#  'North Atlantic Books': 1998,
#  "Kamapua'a Press": 1996,
#  'Bridge Publications': '1993',
#  'Skylark': '1993',
#  'Moderne Verlagsges. Mvg': '2001',
#  'Eichborn': 2002,
#  'Leisure Arts': 1991,
#  'Nelson Bibles': '2002',
#  'Bob Jones Univ Pr': '1998',
#  'LanctÃ´t Ã©diteur': 1998,
#  'Small Beer Press': 2001,
#  'Feminist Press': '1998',
#  'Thomas Nelson Publishers': 2000,
#  'New American Library': 2003,
#  'New Amer Library Classics': 1984,
#  'Vintage Books': 2000,
#  'Times Books': 2002,
#  'Colleccion Millenium': '2002',
#  'State University of New York Press': 1990,
#  'Basic Books': 2001,
#  'Perseus Books Group': 1979,
#  'Noonday Press': '1995',
#  'Clarkson N Potter Publishers': 2001,
#  'Columbia University Press': 2003,
#  'Scarlet Books': '1997',
#  'New Amer Library (Mm)': 1982,
#  'Bet Books': 2004,
#  'Gustav Lubbe Verlag GmbH': '1998',
#  'DenoÃ?Â«l': '1998',
#  'GlÃ?Â©nat': '1999',
#  'Presses de la CitÃ?Â©': '1999',
#  'Presses De La Cite French': 2002,
#  'Advance Publishers LLC': '1983',
#  "Barron's Educational Series": 1997,
#  'Replica Books': 1998,
#  'Orchard Books': 1991,
#  'Continental Book Company': 1998,
#  'Audio Renaissance': 1990,
#  'Prentice Hall': 1988,
#  'Smithsonian Inst Pr': '1991',
#  'Univ of Nebraska Pr': 1991,
#  'Harvill Press': '1998',
#  'Chronicle Books Llc': 1987,
#  'Publications International': 1991,
#  'Story Line Press': 1994,
#  'Anchor Books/Doubleday': 1985,
#  'For Dummies': 2000,
#  'Workman Pub Co': 1986,
#  'Hawks Flight &amp; Association': 2001,
#  'Listen &amp; Live Audio': '1998',
#  'City Lights Publishers': 2003,
#  'Bedford Books': 2004,
#  'Hobblebush Books': 1997,
#  'USCCB': 2000,
#  'Our Sunday Visitor': '1998',
#  'US': 1998,
#  'Ignatius Press': '1998',
#  'Broadman &amp; Holman Pub': 1977,
#  'Kensington Publishing Corporation': 1993,
#  'Rizzoli Publications': 1994,
#  "Distribooks Int'l+inc": '0',
#  'Thorndike Press': 2000,
#  'Stoddart Kids': 2001,
#  'Bridge Pubns': 1990,
#  'Little Brown UK Ltd': 2001,
#  'Photografix': 1996,
#  "Beaver's Pond Press": '2002',
#  'Perigee Trade': 2000,
#  'Btb Bei Goldmann': 1999,
#  'Oxford Univ Pr': 1987,
#  'Graywolf Press': 1992,
#  "New York Review Children's Collection": 2004,
#  'Random House UK Ltd (A Division of Random House Group)': 1993,
#  'University of Queensland Pr (Australia)': '1993',
#  'Galahad': '2004',
#  'Authors Choice Press': '2001',
#  'Intl Specialized Book Service Inc': 1988,
#  'Zondervan Publishing House': '1987',
#  'Diamond Communications': 1996,
#  'Graham, Billy Evangelistic Association': 2000,
#  'Black Classic Press': '1990',
#  'Harper &amp; Row': 1988,
#  'Random House (Merchandising)': 1979,
#  'Mason/Charter': '1977',
#  'Orca Book Publishers': 2002,
#  'Good News Pub': '1993',
#  'University of Minnesota Press': '1995',
#  'Sybex Inc': 1998,
#  'Book Sales': 1985,
#  'Leisure Books': 1998,
#  'Guinness Records': 1998,
#  'Thomson Texere': '2000',
#  'Chrysalis Books': 1994,
#  'Financial Times/Prentice Hall': 2000,
#  'McGraw-Hill/Irwin': 1999,
#  'John Wiley &amp; Sons': 1989,
#  'Black Dog &amp; Leventhal Publishers': 1998,
#  'Flamingo': '2002',
#  'Weiser Books': 1996,
#  'Fair Winds Press': 2001,
#  'Penguin Putnam~childrens Hc': 0,
#  'Alfaguara Ediciones, S.A. (Spain)': 2001,
#  'Ediciones Lengua de Trapo': 2003,
#  'Klett': 1992,
#  'Starscape Books': 2002,
#  'Farrar, Straus and Giroux': '1988',
#  'Perennial Currents': 1999,
#  'Miramax Kids': '2004',
#  "Writer's Digest Books": 1991,
#  'Peachpit Press': '1998',
#  'Perigee Books': 2002,
#  'Random House Value Pub': 2000,
#  'Grosset &amp; Dunlap': 2004,
#  'VIZ LLC': 2000,
#  'Pan Books Ltd': 0,
#  'HarperCollinsPublishers': '1992',
#  'Plaza &amp; Janes Editores, S.A.': 2003,
#  'Dorling Kindersley': 2004,
#  'Warner Books> C/o Little Br': 0,
#  'Barnes &amp; Noble Books-Imports': 2003,
#  'Overlook Press': 1994,
#  'Harperaudio': 1985,
#  'Lexington-Marshall Pub.': 1997,
#  'Tor Classics': '1998',
#  'Anchor Canada': 1994,
#  'Mandarin': 1993,
#  'Acacia Press, Inc.': 1999,
#  'Ebury Press': '1985',
#  'BBC Consumer Publishing': 1993,
#  'Edhasa': '1999',
#  'Aspect': 2000,
#  'Time-Life Books': 1999,
#  'Inner Traditions International': 2001,
#  'Santillana USA Publishing Company': '1999',
#  'Alfaguara': 2000,
#  'Simon Spotlight Entertainment': 1999,
#  'Suma de Letras': 2001,
#  'Arthur A. Levine Books': '2003',
#  'Harlequin Books SA': 1987,
#  'Dorling Kindersley Publishing': 1999,
#  'Harlequin Enterprises Limited': '1987',
#  'Zebra/pinnacle Books': 1993,
#  'Baldini &amp; Castoldi': 1995,
#  'Punto de Lectura': 2001,
#  'Scott Foresman (Pearson K-12)': 1996,
#  'A Different Voice Publishing Co.': 2001,
#  'Bison': '1997',
#  "Reader's Digest Association": 2002,
#  'Editions 84': 0,
#  'Rivages': 1989,
#  'Sudamericana': 1999,
#  'Ediciones Catedra S.A.': 1993,
#  'Audio Literature': 1999,
#  'Winepress Publishing': '1998',
#  'Pelanduk Publications': 2000,
#  'Crown Business': 2001,
#  'ACE Charter': 1984,
#  'American Psychiatric Association': '1987',
#  'Robert Rose': '2000',
#  'Starscape': '2003',
#  'Liveright Publishing Corporation': '2002',
#  'McGraw-Hill Humanities/Social Sciences/Languages': 2000,
#  'Clearbridge Publishing': 2003,
#  'Souvenir Press': '1999',
#  'Tuttle Publishing': 2001,
#  'Random House Uk Ltd': '1998',
#  'Hodder Headline Australia': 2002,
#  'Methuen Publishing Ltd': 2002,
#  "Random House Children's Books (A Division of Random House Group)": 1974,
#  'Scherz': 2002,
#  'Midena': 2000,
#  "Writer's Showcase Press": 2001,
#  'Maverick Publications': 2000,
#  'Barbour Publishing': 1998,
#  'Waterbrook Press': 2002,
#  'Kodansha America': 1985,
#  'New Harbinger Publications': 2001,
#  'Gotham Books': '2004',
#  'Michael Joseph': '2000',
#  'Heinemann': 1995,
#  'Phoenix mass market p/bk': '1992',
#  'Hodder Arnold Teach Yourself': 1999,
#  'Gramercy': 1988,
#  'Pearson Higher Education': 2000,
#  'Prentice Hall Art': 2001,
#  'Highbridge Audio': 1997,
#  'Algonquin Books of Chapel Hill': 1994,
#  'Cumberland House Publishing': 1998,
#  'Career Press': '1998',
#  'Alemany Press': 1983,
#  'Jeremy P. Tarcher': 2003,
#  'Orbit Book Co.': 2003,
#  'Downtown Press': 2005,
#  'Globe Fearon': '1994',
#  'Booksource': 1993,
#  'Scholastic Library Pub': 1988,
#  'AVON': 1998,
#  'Longstreet Press': '1990',
#  'Living Books': '2001',
#  'J. Laughlin': 1963,
#  'InterVarsity Press': 1984,
#  'Judy Piatkus Publishers Ltd': 1997,
#  'Universale Economica Feltrinelli': 1994,
#  'Time Warner Audio Major': 2000,
#  'Notrya Editora': 1993,
#  'NÃ³rdica': 1985,
#  'Rocco': 1996,
#  'Historia 16': 1984,
#  'Gramercy Books': 1994,
#  'Peter Bedrick Books': '2001',
#  'Parkgate Books': 0,
#  'Routledge &amp; K. Paul': 1978,
#  'Fulcrum Publishing': 1996,
#  'Parkwest Publications': '2002',
#  'Firefly Books Ltd': 1992,
#  'Transworld Publishers Ltd': 1989,
#  'Dalesman Publishing Company Ltd': '1991',
#  'Saturday Review Press': '1972',
#  'Ramparts Press': 1973,
#  'South End Press': 1995,
#  'University of Chicago Press': 1966,
#  'New Press': 2001,
#  'Alternate Sources': 1993,
#  'Haworth Press': '1997',
#  'Random House Audio': 1998,
#  'Hay House': 2000,
#  'Penguin Putnam': 1994,
#  'New World Library': 1997,
#  'HarperAudio': 1990,
#  'McGraw Hill - NTC': '1982',
#  'Carol Pub Group': 1992,
#  'Bulfinch Press': 1997,
#  'Bhaktivedanta Book Trust': 1973,
#  'Brooks Cole': 2001,
#  'W.H. Freeman &amp; Company': 1996,
#  'Educational Development Corporation': 1991,
#  'Meadowbrook': 1998,
#  'Horizon': 2001,
#  'Penguin Putnam Books for Young Readers': 2002,
#  'Jones &amp; Bartlett Pub': '2002',
#  'W H Freeman &amp; Co': 1995,
#  'Family CareWare, Inc.': 1998,
#  'B.T. Batsford': '2002',
#  'Chess Enterprises': 1998,
#  'Nuova Eri Rizzoli': 1995,
#  'Random House Large Print': 2003,
#  'Pond Publishing': 2003,
#  'Hoffmann &amp; Campe': 1998,
#  'Edaf': 2000,
#  'Planeta Pub Corp': 2002,
#  'Valdemar': '1998',
#  'Grupo Zeta': 1999,
#  'Debate': '1999',
#  'Ediciones SM': '1984',
#  'Apple': 2001,
#  'Adams Media Corporation': 1999,
#  'Signet Books': '1978',
#  'University of North Carolina Press': 1991,
#  'Mountaineers Books': 1993,
#  'Skylark Books': 1998,
#  'John M. Hardy': 2002,
#  'Macromedia Press': '2002',
#  'Warner Forever': '2004',
#  'Morrow Cookbooks': 2003,
#  'ReganBooks': 2000,
#  'Currency': 1996,
#  'Consortium Book Sales &amp; Dist': 1998,
#  'Wildcat Canyon Press': '1997',
#  'Frog Ltd.': 1994,
#  'Landowner Planning Center': 1998,
#  "Simon &amp; Schuster Children's Publishing": 1999,
#  'Lectorum Publications': '1999',
#  'University of Illinois Press': 1987,
#  'Dawnsign Press': 1988,
#  'Deaf Life Press': 1992,
#  'Temple University Press': '2001',
#  'Holt Rinehart and Winston': 1979,
#  'Real Comet Press': '1987',
#  'Weatherhill Inc.': 1987,
#  'Linstok Press, Incorporated': 1989,
#  'Thorsons Publishers': '1999',
#  'Healing Art Press': 1999,
#  'Bookking International': 2000,
#  'Actes Sud': '1999',
#  'Le Livre de Poche': '1991',
#  'Donning Company Publishers': '1980',
#  'Independent Pub Group': 1992,
#  'Guernica Editions': '2002',
#  'Xlibris Corporation': 2001,
#  'Editions QuÃ©bec/AmÃ©rique': '1993',
#  'Carhil Ventures, LLC': 2003,
#  'DAW Books': '1985',
#  'Diogenes Verlag AG': '0',
#  'Llewellyn Pubns': 1994,
#  'Morgan &amp; Morgan, Inc.': '1979',
#  'distributed by Houghton Mifflin': 1980,
#  'Integrity Publishers': '2004',
#  'Revell': 1998,
#  'Red Sage Publishing,Inc': 1997,
#  'Collier Books': 1930,
#  'Dorset Press': 1995,
#  'Pan Publishing': '1997',
#  'McFarland &amp; Company': 2000,
#  'Yale University Press': 1988,
#  'Writings of Mary Baker Eddy': '1991',
#  'University of Washington Press': 1995,
#  'University of Hawaii Press': 1989,
#  'University of Georgia Press': 1999,
#  'University of Massachusetts Press': '1998',
#  'Arte Publico Press': 1997,
#  'Houghton Mifflin College': 1981,
#  'Publicacoes Europa-America': 0,
#  'Seal Press (WA)': 2002,
#  'Publishamerica': '2003',
#  'Walk Worthy Press': 2003,
#  'Christian Publications': '1996',
#  'Bethany House Publishers': 2001,
#  'Upfront Publishing': 2002,
#  'Ullstein TB-Vlg': '2002',
#  'Wilhelm Goldmann Verlag, GmbH': 2001,
#  'Claassen Verlag': 2003,
#  'Kiepenheuer &amp; Witsch GmbH &amp; Co. KG, Verlag': '2001',
#  'Gulliver Books Paperbacks': '1995',
#  'Selldowns/no More Orders': 0,
#  'Baen Books': 1989,
#  'Simon &amp; Schuster Books': 1975,
#  'Fourth Estate Ltd': 0,
#  'Troll Communications': 2002,
#  'Plough Publishing House': 2000,
#  'Teri Woods Publishing': 1999,
#  'Durkin Hayes Publishing Ltd.': '1999',
#  'Deseret Book Company': 1996,
#  'Simon Spotlight': 2003,
#  'Obelisco': 1997,
#  'Prime Crime': 1998,
#  'Macmillan Pub Co': '1964',
#  'Chelsea Green Publishing Company': 1997,
#  'Thames &amp; Hudson': 2000,
#  'Great Quotations': '1997',
#  '10x18': 1999,
#  'Fischer Taschenbuch Verlag': '0',
#  'Van Nostrand Reinhold/co Wiley': '0',
#  'TSR': 1999,
#  'PublicAffairs': '2004',
#  'DaCapo Press': '2002',
#  'Fromm Intl': 1994,
#  'Short Books, London': '2003',
#  'McGraw-Hill/Dushkin': 1999,
#  'Arbor House Pub Co': 1983,
#  'BBS Publishing Corporation': '1994',
#  'Baldini e Castoldi': 0,
#  'Wunderlich im Rowohlt': 2000,
#  'Heyne GmbH &amp; Co. KG, Verlag': 1999,
#  'Bloomsbury': 1991,
#  'St Martins Press': 0,
#  'Storey Books': 2001,
#  'SunShine Press Publications': '1999',
#  'Owl Books (NY)': 1999,
#  'Macmillan Pub Ltd': '2002',
#  'Adelphi': '1998',
#  'Farrar, Straus and Giroux (BYR)': 1995,
#  'Sweet Valley': 1988,
#  'American Girl': 2003,
#  'Kids Books Inc': 1997,
#  'Little Apple': 2003,
#  'Maverick Books': 1988,
#  'North Point Press': 1999,
#  'Editorial Laertes': 1989,
#  'HCI Teens': 2000,
#  'Greenery Press (CA)': '2000',
#  'Sybex': 1997,
#  'Plaza &amp; JanÃ©s Editores': 2000,
#  'Scribner Book Company': 1984,
#  'Triumph Books': 2004,
#  'Caminho': '1993',
#  'Phaidon Press': 1994,
#  'Conari Press': 2002,
#  'Tor Science Fiction': '2000',
#  'Worldwide Library': 1997,
#  'iUniverse, Inc.': '2004',
#  'The Penguin Press HC': '2004',
#  'Paul Dry Books': 2002,
#  'Hill and Wang': 1984,
#  'Robin Book': '1996',
#  'Espasa Calpe Mexicana, S.A.': '1996',
#  'Santillana Publishing Co Inc': 0,
#  'Mercure de France': '2003',
#  'B. Grasset': '1985',
#  'Lgf': '2002',
#  'Jouvence': '1998',
#  'Pocket (FR)': '2001',
#  'Counterpoint Press': 2001,
#  'Prima Lifestyles': 1997,
#  'Random House~trade': 1988,
#  'Orion mass market paperback': 0,
#  'Ten Speed Press': 1993,
#  'Dial Press': 2001,
#  'Naval Institute Press': 1994,
#  'Greenhill Books': '2000',
#  'Montana Historical Society': 1997,
#  'Scarborough House Publishers': 1993,
#  'French &amp; European Pubns': 1982,
#  'Random House Trade': 1997,
#  'Thames and Hudson': '1979',
#  'Franklin Watts': 1997,
#  "Bedford/St. Martin's": 1993,
#  'Da Capo Press': 1982,
#  'Dk Pub': 1997,
#  'MJF Books': 1997,
#  'Research &amp; Education Association': '1988',
#  'Prelude Press': '1997',
#  'W. SÃ¶derstrÃ¶m': 1988,
#  'Chronicle Books': 2001,
#  'Southwest Parks &amp; Monuments Association': '1994',
#  'Faber Paperbacks': '2000',
#  'Lethe Press': '2001',
#  'Little Brown Company': 0,
#  'Sceptre': '2001',
#  'R. Laffont': '1991',
#  'Penguin Uk': 1999,
#  'Emece Editores': 2001,
#  'Mondadori (IT)': '2000',
#  'Barnes Noble': 0,
#  'Seven Stories Press': 1999,
#  'Grove/Atlantic': 1988,
#  'Amereon Ltd': 1981,
#  'Greenwillow': 1990,
#  'Fourth Estate': 2000,
#  'Running Press Book Publishers': 2002,
#  'Loveswept': 1993,
#  'Transworld Publishers (Division of Random House Australia)': '0',
#  'Astran Inc': 2001,
#  'J.M. Dent &amp; Sons': 1991,
#  'Bard Press (TX)': '2000',
#  'Fitzhenry &amp; Whiteside Limited': '1992',
#  'Rodale Press': 1977,
#  'Ultramarine Pub Co': '1979',
#  'H. Hamilton': '1995',
#  'Stoddart': 1998,
#  'Domain': '1996',
#  'Oetinger Verlag': 1983,
#  'American Philological Association': '1993',
#  'Shelter Publications': '1983',
#  'Odyssey Classics': '2002',
#  'Tusquets Editores': '2003',
#  'Huerga &amp; Fierro': 1996,
#  'GÃ?Â¼tersloher Verlagshaus': '2003',
#  'Arango Editores': 1988,
#  'Carl Hanser': 2001,
#  'Droemer Knaur': 2000,
#  'Eos (HarperCollins)': '2000',
#  'Headline': 1991,
#  'Orion': '0',
#  'Lb May &amp; Assoc Inc': 1999,
#  'Sagebrush Education Resources': 1999,
#  'Addison-Wesley Pub Co (Sd)': 1990,
#  'Editions du ChÃ?Âªne': 1999,
#  'Henry Holt &amp; Company, Inc.': 1996,
#  "Fodor's Travel Publications": 1998,
#  'Editorial Barcanova': 1996,
#  'Mateos Ediciones': '1998',
#  'La Campana': 1997,
#  'Courage Books': 1985,
#  'Disney Pr': 1992,
#  'Brimax Books Ltd': 1994,
#  'Unicorn Publishing House': 1987,
#  'Unicorn Publishing House, The Incorporated': 1986,
#  'Rutledge Hill Press': 2000,
#  'Glowworm Books Ltd': 1994,
#  'Macmillan General Reference': 1978,
#  'Park Lane': '0',
#  'Anvil Press': '2000',
#  'Three Rivers Press (CA)': 1998,
#  'Chicago Review Press': 2004,
#  'Philomel Books': 1994,
#  'Doubleday Books for Young Readers': '1988',
#  'Grafton Books': '0',
#  'Pelican Publishing Company': 2001,
#  'Hodder &amp; Stoughton': 1986,
#  'Berkley Pub Group (Mm)': 1979,
#  'Ediciones Urano': 2002,
#  'Price Stern Sloan Pub (J)': 1986,
#  'Key Porter Books': '1986',
#  'Princeton University Press': 1986,
#  'Lonely Planet Publications': 2003,
#  'Iowa State Press': 1996,
#  'Tyndale Kids': 2000,
#  'Broadview Press': '2003',
#  'Coconut Info': 1999,
#  'Promise Press': 2000,
#  'Longman': 2004,
#  'Turnkey Press': 2003,
#  'Douglas &amp; McIntyre': '1986',
#  'Random House Childrens Pub': 1976,
#  'Sirio': '2001',
#  'Piramide': '1998',
#  'Destino Ediciones': '2004',
#  'Summit Books': 1987,
#  'A. J. Muste Memorial Institute': 1982,
#  'Canongate Books': 2004,
#  'Scholastic Paperbacks (T)': 1984,
#  'Amistad': '1999',
#  'Meisha Merlin Pub': 2003,
#  'Vintage Canada': 2002,
#  'Perseus Publishing': 2001,
#  'Johns Hopkins University Press': 1996,
#  'Writers Club Press': 2000,
#  'Warner Books Inc': 1994,
#  'HarperBusiness': 2002,
#  'Invincible Books': 2002,
#  'Cliffs Notes': 1964,
#  'Octopus Publising Group Plc': '0',
#  'Herald Press (PA)': '1969',
#  'Santillana S.A.': 1998,
#  'Walker &amp; Company': 2002,
#  'Planeta': 1979,
#  'Edicions El Jonc': 2001,
#  'Virus': 1992,
#  'Editorial Planeta, S.A.': '0',
#  ...}

# %%
## Replacing Invalid years with max year
from collections import Counter
count = Counter(book['Year-Of-Publication'])
[k for k, v in count.items() if v == max(count.values())]
# Out:
# [2002]

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   """Entry point for launching an IPython kernel.

# %%
book.loc[book["Year-Of-Publication"] == 'DK Publishing Inc', :]
# Out:
#               ISBN  \
# 209538  078946697X
# 221678  0789466953
#
#                                                                                                          Book-Title  \
# 209538  DK Readers: Creating the X-Men, How It All Began (Level 4: Proficient Readers)\";Michael Teitelbaum"
# 221678  DK Readers: Creating the X-Men, How Comic Books Come to Life (Level 4: Proficient Readers)\";James Buckley"
#
#        Book-Author Year-Of-Publication  \
# 209538  2000        DK Publishing Inc
# 221678  2000        DK Publishing Inc
#
#                                                            Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.01.THUMBZZZ.jpg
# 221678  http://images.amazon.com/images/P/0789466953.01.THUMBZZZ.jpg
#
#                                                          Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.01.MZZZZZZZ.jpg
# 221678  http://images.amazon.com/images/P/0789466953.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-M  \
# 209538  http://images.amazon.com/images/P/078946697X.01.LZZZZZZZ.jpg
# 221678  http://images.amazon.com/images/P/0789466953.01.LZZZZZZZ.jpg
#
#        Image-URL-L
# 209538  NaN
# 221678  NaN

# %%
book.loc[book.ISBN == '0789466953','Year-Of-Publication'] = 2000
book.loc[book.ISBN == '0789466953','Book-Author'] = "James Buckley"
book.loc[book.ISBN == '0789466953','Publisher'] = "DK Publishing Inc"
book.loc[book.ISBN == '0789466953','Book-Title'] = "DK Readers: Creating the X-Men, How Comic Book...	"

# %%
book.loc[book["ISBN"] == '0789466953',:]
# Out:
#               ISBN                                           Book-Title  \
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...\t
#
#           Book-Author Year-Of-Publication          Publisher  \
# 221678  James Buckley  2000                DK Publishing Inc
#
#                                                          Image-URL-S  \
# 221678  http://images.amazon.com/images/P/0789466953.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-M  \
# 221678  http://images.amazon.com/images/P/0789466953.01.LZZZZZZZ.jpg
#
#        Image-URL-L
# 221678  NaN

# %%
book.loc[book.ISBN == '078946697X','Year-Of-Publication'] = 2000
book.loc[book.ISBN == '078946697X','Book-Author'] = "JMichael Teitelbaum"
book.loc[book.ISBN == '078946697X','Publisher'] = "DK Publishing Inc"
book.loc[book.ISBN == '078946697X','Book-Title'] = "DK Readers: Creating the X-Men, How It All Beg..."

# %%
book.loc[book.ISBN == '2070426769','Year-Of-Publication'] = 2003
book.loc[book.ISBN == '2070426769','Book-Author'] = "Jean-Marie Gustave Le ClÃ?Â©zio"
book.loc[book.ISBN == '2070426769','Publisher'] = "Gallimard"
book.loc[book.ISBN == '2070426769','Book-Title'] = "Peuple du ciel, suivi de Les Bergers"

# %%
## Converting year of publication in Numbers
book['Year-Of-Publication'] = book['Year-Of-Publication'].astype(int)

# %%
book.loc[book['Year-Of-Publication'] > 2021, 'Year-Of-Publication'] = 2000
book.loc[book['Year-Of-Publication'] == 0, 'Year-Of-Publication'] = 2000

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  int64
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 16.6+ MB

# %%
User=pd.read_csv("Users.csv")

# %%
User
# Out:
#         User-ID                            Location   Age
# 0       1        nyc, new york, usa                 NaN
# 1       2        stockton, california, usa           18.0
# 2       3        moscow, yukon territory, russia    NaN
# 3       4        porto, v.n.gaia, portugal           17.0
# 4       5        farnborough, hants, united kingdom NaN
# ...    ..                                       ...  ..
# 278853  278854   portland, oregon, usa              NaN
# 278854  278855   tacoma, washington, united kingdom  50.0
# 278855  278856   brampton, ontario, canada          NaN
# 278856  278857   knoxville, tennessee, usa          NaN
# 278857  278858   dublin, n/a, ireland               NaN
#
# [278858 rows x 3 columns]

# %%
User["country"]=User.Location.str.split(",",expand=True)[2]

# %%
User
# Out:
#         User-ID                            Location   Age          country
# 0       1        nyc, new york, usa                 NaN     usa
# 1       2        stockton, california, usa           18.0   usa
# 2       3        moscow, yukon territory, russia    NaN     russia
# 3       4        porto, v.n.gaia, portugal           17.0   portugal
# 4       5        farnborough, hants, united kingdom NaN     united kingdom
# ...    ..                                       ...  ..                ...
# 278853  278854   portland, oregon, usa              NaN     usa
# 278854  278855   tacoma, washington, united kingdom  50.0   united kingdom
# 278855  278856   brampton, ontario, canada          NaN     canada
# 278856  278857   knoxville, tennessee, usa          NaN     usa
# 278857  278858   dublin, n/a, ireland               NaN     ireland
#
# [278858 rows x 4 columns]

# %%
User=User.drop(["Location"],axis=1)

# %%
len(User["country"].unique())
# Out:
# 1110

# %%
User.isna().sum()
# Out:
# User-ID    0
# Age        110762
# country    2
# dtype: int64

# %%
#age features null percentage=110762/278858=39%

# %%
import seaborn as sns
sns.histplot(User["Age"],bins=20)

# %%
# from above chat we can consider that most reader is from age group of 25 to 37,therefore iam taking 30. for all null values.

# %%
User["Age"].value_counts()# we can see that above 100 all are invalid or outlier and less in number.
# Out:
# 24.0     5687
# 25.0     5618
# 26.0     5547
# 23.0     5456
# 27.0     5383
#          ...
# 168.0    1
# 132.0    1
# 159.0    1
# 186.0    1
# 127.0    1
# Name: Age, Length: 165, dtype: int64

# %%
User.loc[User["Age"]>100,"Age"]=np.NaN
User.loc[User["Age"]<6,"Age"]=np.NaN

# %%
User["Age"].values
# Out:
# array([nan, 18., nan, ..., nan, nan, nan])

# %%
User["Age"].fillna(30,inplace = True)

# %%
User["Age"]=User["Age"].astype(int)

# %%
import seaborn as sns
sns.histplot(User["Age"],bins=10)

# %%
User.dropna()#there are only two null value in country therefore droping it
# Out:
#         User-ID  Age          country
# 0       1        30    usa
# 1       2        18    usa
# 2       3        30    russia
# 3       4        17    portugal
# 4       5        30    united kingdom
# ...    ..        ..               ...
# 278853  278854   30    usa
# 278854  278855   50    united kingdom
# 278855  278856   30    canada
# 278856  278857   30    usa
# 278857  278858   30    ireland
#
# [278856 rows x 3 columns]

# %%
User["country"].value_counts()
# Out:
#  usa                139187
#  canada             21558
#  united kingdom     18286
#  germany            17022
#  spain              13095
#                     ...
#  can                1
#  disrito federal    1
#  los angeles        1
#  sicilia            1
#  united kingdom.    1
# Name: country, Length: 1109, dtype: int64

# %%
rating=pd.read_csv("/content/Ratings.csv")

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0  276725   034545104X  0
# 1  276726   0155061224  5
# 2  276727   0446520802  0
# 3  276729   052165615X  3
# 4  276729   0521795028  6

# %%
rating.info()
rating.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
import re
## removing extra characters from ISBN (from ratings dataset) existing in books dataset
bookISBN = book['ISBN'].tolist() 
reg = "[^A-Za-z0-9]" 
for index, row_Value in rating.iterrows():
    z = re.search(reg, row_Value['ISBN'])    
    if z:
        f = re.sub(reg,"",row_Value['ISBN'])
        if f in bookISBN:
            rating.at[index , 'ISBN'] = f

# %%
rating
# Out:
#          User-ID         ISBN  Book-Rating
# 0        276725   034545104X   0
# 1        276726   0155061224   5
# 2        276727   0446520802   0
# 3        276729   052165615X   3
# 4        276729   0521795028   6
# ...         ...          ...  ..
# 1149775  276704   1563526298   9
# 1149776  276706   0679447156   0
# 1149777  276709   0515107662   10
# 1149778  276721   0590442449   10
# 1149779  276723   05162443314  8
#
# [1149780 rows x 3 columns]

# %%
# merging all data sets
dataset = pd.merge(book, rating, on='ISBN', how='inner')
dataset = pd.merge(dataset, User, on='User-ID', how='inner')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1031476 entries, 0 to 1031475
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   ISBN                 1031476 non-null  object
#  1   Book-Title           1031476 non-null  object
#  2   Book-Author          1031475 non-null  object
#  3   Year-Of-Publication  1031476 non-null  int64
#  4   Publisher            1031474 non-null  object
#  5   Image-URL-S          1031476 non-null  object
#  6   Image-URL-M          1031476 non-null  object
#  7   Image-URL-L          1031472 non-null  object
#  8   User-ID              1031476 non-null  int64
#  9   Book-Rating          1031476 non-null  int64
#  10  Age                  1031476 non-null  int64
#  11  country              1031476 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 102.3+ MB

# %%
dataset
# Out:
#                ISBN  \
# 0        0195153448
# 1        0002005018
# 2        0060973129
# 3        0374157065
# 4        0393045218
# ...             ...
# 1031471  087004124X
# 1031472  158243123X
# 1031473  8485900057
# 1031474  0838934854
# 1031475  3423300965
#
#                                                                                                  Book-Title  \
# 0        Classical Mythology
# 1        Clara Callan
# 2        Decision in Normandy
# 3        Flu: The Story of the Great Influenza Pandemic of 1918 and the Search for the Virus That Caused It
# 4        The Mummies of Urumchi
# ...                         ...
# 1031471  Anthem
# 1031472  A Student of Weather
# 1031473  Rimas y leyendas (ClÃ¡sicos Fraile ; 3)
# 1031474  Anglo-American Cataloguing Rules
# 1031475  Texte zur Ethik.
#
#                      Book-Author  Year-Of-Publication  \
# 0        Mark P. O. Morford       2002
# 1        Richard Bruce Wright     2001
# 2        Carlo D'Este             1991
# 3        Gina Bari Kolata         1999
# 4        E. J. W. Barber          1999
# ...                  ...           ...
# 1031471  Ayn Rand                 1966
# 1031472  Elizabeth Hay            2001
# 1031473  Gustavo Adolfo BÃ©cquer  1981
# 1031474  Michael Gorman           1998
# 1031475  Dieter Birnbacher        2003
#
#                             Publisher  \
# 0        Oxford University Press
# 1        HarperFlamingo Canada
# 2        HarperPerennial
# 3        Farrar Straus Giroux
# 4        W. W. Norton &amp; Company
# ...                             ...
# 1031471  Caxton Press
# 1031472  Counterpoint Press
# 1031473  Ediciones Fraile
# 1031474  American Library Association
# 1031475  Dtv
#
#                                                           Image-URL-S  \
# 0        http://images.amazon.com/images/P/0195153448.01.THUMBZZZ.jpg
# 1        http://images.amazon.com/images/P/0002005018.01.THUMBZZZ.jpg
# 2        http://images.amazon.com/images/P/0060973129.01.THUMBZZZ.jpg
# 3        http://images.amazon.com/images/P/0374157065.01.THUMBZZZ.jpg
# 4        http://images.amazon.com/images/P/0393045218.01.THUMBZZZ.jpg
# ...                                                               ...
# 1031471  http://images.amazon.com/images/P/087004124X.01.THUMBZZZ.jpg
# 1031472  http://images.amazon.com/images/P/158243123X.01.THUMBZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.THUMBZZZ.jpg
# 1031474  http://images.amazon.com/images/P/0838934854.01.THUMBZZZ.jpg
# 1031475  http://images.amazon.com/images/P/3423300965.01.THUMBZZZ.jpg
#
#                                                           Image-URL-M  \
# 0        http://images.amazon.com/images/P/0195153448.01.MZZZZZZZ.jpg
# 1        http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg
# 2        http://images.amazon.com/images/P/0060973129.01.MZZZZZZZ.jpg
# 3        http://images.amazon.com/images/P/0374157065.01.MZZZZZZZ.jpg
# 4        http://images.amazon.com/images/P/0393045218.01.MZZZZZZZ.jpg
# ...                                                               ...
# 1031471  http://images.amazon.com/images/P/087004124X.01.MZZZZZZZ.jpg
# 1031472  http://images.amazon.com/images/P/158243123X.01.MZZZZZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.MZZZZZZZ.jpg
# 1031474  http://images.amazon.com/images/P/0838934854.01.MZZZZZZZ.jpg
# 1031475  http://images.amazon.com/images/P/3423300965.01.MZZZZZZZ.jpg
#
#                                                           Image-URL-L  \
# 0        http://images.amazon.com/images/P/0195153448.01.LZZZZZZZ.jpg
# 1        http://images.amazon.com/images/P/0002005018.01.LZZZZZZZ.jpg
# 2        http://images.amazon.com/images/P/0060973129.01.LZZZZZZZ.jpg
# 3        http://images.amazon.com/images/P/0374157065.01.LZZZZZZZ.jpg
# 4        http://images.amazon.com/images/P/0393045218.01.LZZZZZZZ.jpg
# ...                                                               ...
# 1031471  http://images.amazon.com/images/P/087004124X.01.LZZZZZZZ.jpg
# 1031472  http://images.amazon.com/images/P/158243123X.01.LZZZZZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.LZZZZZZZ.jpg
# 1031474  http://images.amazon.com/images/P/0838934854.01.LZZZZZZZ.jpg
# 1031475  http://images.amazon.com/images/P/3423300965.01.LZZZZZZZ.jpg
#
#          User-ID  Book-Rating  Age   country
# 0        2        0            18    usa
# 1        8        5            30    canada
# 2        8        0            30    canada
# 3        8        0            30    canada
# 4        8        0            30    canada
# ...     ..       ..            ..       ...
# 1031471  259589   8            19    usa
# 1031472  259591   8            39    usa
# 1031473  259614   10           22    spain
# 1031474  259679   6            27    usa
# 1031475  259920   0            30    germany
#
# [1031476 rows x 12 columns]

# %%
p = {}
for year in book['Year-Of-Publication']:
    if str(year) not in p:
        p[str(year)] = 0
    p[str(year)] +=1

p = {k:v for k, v in sorted(p.items())}

# %%
plt.figure(figsize=(15,6))
sns.countplot(y="Book-Author", data=book,order=book['Book-Author'].value_counts().index[0:10])

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="Book-Rating", data=rating)

# %%
plt.figure(figsize=(15,8))
sns.countplot(y="country", data=User, order=User['country'].value_counts().index[0:10])
plt.title("No of readers from each country (Top 10)")
# Out:
# Text(0.5, 1.0, 'No of readers from each country (Top 10)')

# %%
plt.figure(figsize=(15,8))
sns.countplot(y="Book-Title", data=dataset, order=dataset['Book-Title'].value_counts().index[0:10])

# %%
dataset1=dataset[dataset["Book-Rating"]>8]

# %%
dataset1
# Out:
#                ISBN  \
# 19       0786868716
# 27       014025448X
# 31       0060958022
# 82       0399135782
# 85       0440234743
# ...             ...
# 1031447  0452283582
# 1031456  051758977X
# 1031459  3548248667
# 1031463  0030209692
# 1031473  8485900057
#
#                                                                   Book-Title  \
# 19       The Five People You Meet in Heaven
# 27       At Home in Mitford (The Mitford Years)
# 31       Five Quarters of the Orange
# 82       The Kitchen God's Wife
# 85       The Testament
# ...                ...
# 1031447  A Whistler in the Nightworld: Short Fiction from the Latin Americas
# 1031456  Sotah
# 1031459  HeimwÃ?Â¤rts. Roman.
# 1031463  Physics for Scientists and Engineers, Volume II
# 1031473  Rimas y leyendas (ClÃ¡sicos Fraile ; 3)
#
#                      Book-Author  Year-Of-Publication         Publisher  \
# 19       Mitch Albom              2003                 Hyperion
# 27       Jan Karon                1996                 Viking Books
# 31       Joanne Harris            2002                 Perennial
# 82       Amy Tan                  1991                 Putnam Pub Group
# 85       John Grisham             1999                 Dell
# ...               ...              ...                  ...
# 1031447  Thomas Colchie           2002                 Plume Books
# 1031456  Naomi Ragen              1992                 Random House Inc
# 1031459  Anne Rivers Siddons      2000                 Ullstein Tb
# 1031463  Raymond A. Serway        1999                 Harcourt
# 1031473  Gustavo Adolfo BÃ©cquer  1981                 Ediciones Fraile
#
#                                                           Image-URL-S  \
# 19       http://images.amazon.com/images/P/0786868716.01.THUMBZZZ.jpg
# 27       http://images.amazon.com/images/P/014025448X.01.THUMBZZZ.jpg
# 31       http://images.amazon.com/images/P/0060958022.01.THUMBZZZ.jpg
# 82       http://images.amazon.com/images/P/0399135782.01.THUMBZZZ.jpg
# 85       http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# ...                                                               ...
# 1031447  http://images.amazon.com/images/P/0452283582.01.THUMBZZZ.jpg
# 1031456  http://images.amazon.com/images/P/051758977X.01.THUMBZZZ.jpg
# 1031459  http://images.amazon.com/images/P/3548248667.01.THUMBZZZ.jpg
# 1031463  http://images.amazon.com/images/P/0030209692.01.THUMBZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.THUMBZZZ.jpg
#
#                                                           Image-URL-M  \
# 19       http://images.amazon.com/images/P/0786868716.01.MZZZZZZZ.jpg
# 27       http://images.amazon.com/images/P/014025448X.01.MZZZZZZZ.jpg
# 31       http://images.amazon.com/images/P/0060958022.01.MZZZZZZZ.jpg
# 82       http://images.amazon.com/images/P/0399135782.01.MZZZZZZZ.jpg
# 85       http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# ...                                                               ...
# 1031447  http://images.amazon.com/images/P/0452283582.01.MZZZZZZZ.jpg
# 1031456  http://images.amazon.com/images/P/051758977X.01.MZZZZZZZ.jpg
# 1031459  http://images.amazon.com/images/P/3548248667.01.MZZZZZZZ.jpg
# 1031463  http://images.amazon.com/images/P/0030209692.01.MZZZZZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.MZZZZZZZ.jpg
#
#                                                           Image-URL-L  \
# 19       http://images.amazon.com/images/P/0786868716.01.LZZZZZZZ.jpg
# 27       http://images.amazon.com/images/P/014025448X.01.LZZZZZZZ.jpg
# 31       http://images.amazon.com/images/P/0060958022.01.LZZZZZZZ.jpg
# 82       http://images.amazon.com/images/P/0399135782.01.LZZZZZZZ.jpg
# 85       http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg
# ...                                                               ...
# 1031447  http://images.amazon.com/images/P/0452283582.01.LZZZZZZZ.jpg
# 1031456  http://images.amazon.com/images/P/051758977X.01.LZZZZZZZ.jpg
# 1031459  http://images.amazon.com/images/P/3548248667.01.LZZZZZZZ.jpg
# 1031463  http://images.amazon.com/images/P/0030209692.01.LZZZZZZZ.jpg
# 1031473  http://images.amazon.com/images/P/8485900057.01.LZZZZZZZ.jpg
#
#          User-ID  Book-Rating  Age       country
# 19       11400    9            49    canada
# 27       11400    10           49    canada
# 31       11400    10           49    canada
# 82       11676    9            30    n/a
# 85       11676    9            30    n/a
# ...        ...   ..            ..    ...
# 1031447  243368   9            30    netherlands
# 1031456  243994   10           30    usa
# 1031459  244667   10           39    germany
# 1031463  245104   10           30    usa
# 1031473  259614   10           22    spain
#
# [132071 rows x 12 columns]

# %%
plt.figure(figsize=(15,6))#8-10 rating author with maxmum count
sns.countplot(y="Book-Author", data=dataset1,order=dataset1['Book-Author'].value_counts().index[0:10])

# %%
dataset2=dataset1[dataset1["Age"]<18]

# %%
dataset2
# Out:
#                ISBN                               Book-Title  \
# 62714    0440234743  The Testament
# 62716    0440157587  Mortal Stakes
# 62717    0425152898  Mind Prey
# 72348    044021145X  The Firm
# 72350    0446364193  Along Came a Spider (Alex Cross Novels)
# ...             ...                                      ...
# 1030770  840132162X  Manaos
# 1030891  9879017056  El Caso de Charles Dexter Ward
# 1031068  3407788738  Von mir @n dich
# 1031081  080502557X  Shizuko's Daughter (Edge Books)
# 1031274  0823413284  Snip, Snip...Snow
#
#                       Book-Author  Year-Of-Publication  \
# 62714    John Grisham              1999
# 62716    Robert B. Parker          1995
# 62717    John Sandford             2004
# 72348    John Grisham              1992
# 72350    James Patterson           1993
# ...                  ...            ...
# 1030770  Alberto Vazquez-Figueroa  1986
# 1030891  Howard Philips Lovecraft  1996
# 1031068  Chris DLacey              2002
# 1031081  Kyoko Mori                1993
# 1031274  Nancy Poydar              1997
#
#                             Publisher  \
# 62714    Dell
# 62716    Dell Publishing Company
# 62717    Berkley Publishing Group
# 72348    Bantam Dell Publishing Group
# 72350    Warner Books
# ...               ...
# 1030770  Lectorum Pubns (Adult)
# 1030891  Altamira
# 1031068  Beltz AthenÃ?Â¤um GmbH
# 1031081  Henry Holt &amp; Company
# 1031274  Holiday House
#
#                                                           Image-URL-S  \
# 62714    http://images.amazon.com/images/P/0440234743.01.THUMBZZZ.jpg
# 62716    http://images.amazon.com/images/P/0440157587.01.THUMBZZZ.jpg
# 62717    http://images.amazon.com/images/P/0425152898.01.THUMBZZZ.jpg
# 72348    http://images.amazon.com/images/P/044021145X.01.THUMBZZZ.jpg
# 72350    http://images.amazon.com/images/P/0446364193.01.THUMBZZZ.jpg
# ...                                                               ...
# 1030770  http://images.amazon.com/images/P/840132162X.01.THUMBZZZ.jpg
# 1030891  http://images.amazon.com/images/P/9879017056.01.THUMBZZZ.jpg
# 1031068  http://images.amazon.com/images/P/3407788738.01.THUMBZZZ.jpg
# 1031081  http://images.amazon.com/images/P/080502557X.01.THUMBZZZ.jpg
# 1031274  http://images.amazon.com/images/P/0823413284.01.THUMBZZZ.jpg
#
#                                                           Image-URL-M  \
# 62714    http://images.amazon.com/images/P/0440234743.01.MZZZZZZZ.jpg
# 62716    http://images.amazon.com/images/P/0440157587.01.MZZZZZZZ.jpg
# 62717    http://images.amazon.com/images/P/0425152898.01.MZZZZZZZ.jpg
# 72348    http://images.amazon.com/images/P/044021145X.01.MZZZZZZZ.jpg
# 72350    http://images.amazon.com/images/P/0446364193.01.MZZZZZZZ.jpg
# ...                                                               ...
# 1030770  http://images.amazon.com/images/P/840132162X.01.MZZZZZZZ.jpg
# 1030891  http://images.amazon.com/images/P/9879017056.01.MZZZZZZZ.jpg
# 1031068  http://images.amazon.com/images/P/3407788738.01.MZZZZZZZ.jpg
# 1031081  http://images.amazon.com/images/P/080502557X.01.MZZZZZZZ.jpg
# 1031274  http://images.amazon.com/images/P/0823413284.01.MZZZZZZZ.jpg
#
#                                                           Image-URL-L  \
# 62714    http://images.amazon.com/images/P/0440234743.01.LZZZZZZZ.jpg
# 62716    http://images.amazon.com/images/P/0440157587.01.LZZZZZZZ.jpg
# 62717    http://images.amazon.com/images/P/0425152898.01.LZZZZZZZ.jpg
# 72348    http://images.amazon.com/images/P/044021145X.01.LZZZZZZZ.jpg
# 72350    http://images.amazon.com/images/P/0446364193.01.LZZZZZZZ.jpg
# ...                                                               ...
# 1030770  http://images.amazon.com/images/P/840132162X.01.LZZZZZZZ.jpg
# 1030891  http://images.amazon.com/images/P/9879017056.01.LZZZZZZZ.jpg
# 1031068  http://images.amazon.com/images/P/3407788738.01.LZZZZZZZ.jpg
# 1031081  http://images.amazon.com/images/P/080502557X.01.LZZZZZZZ.jpg
# 1031274  http://images.amazon.com/images/P/0823413284.01.LZZZZZZZ.jpg
#
#          User-ID  Book-Rating  Age     country
# 62714    75691    9            17    usa
# 62716    75691    9            17    usa
# 62717    75691    9            17    usa
# 72348    102647   10           14    usa
# 72350    102647   10           14    usa
# ...         ...   ..           ..    ...
# 1030770  5513     9            17    spain
# 1030891  167258   9            16    argentina
# 1031068  208744   10           14    germany
# 1031081  209620   9            15    usa
# 1031274  231573   10           14    usa
#
# [3723 rows x 12 columns]

# %%
plt.figure(figsize=(15,6))#8 to 10 rating author with maxmum count and age between 0 to 18
sns.countplot(y="Book-Title", data=dataset2,order=dataset2['Book-Title'].value_counts().index[0:10])

# %%
dataset3=dataset1[dataset1["Age"]>18]

# %%
plt.figure(figsize=(15,6))#8 to 10 rating author with maxmum count and age above 18
sns.countplot(y="Book-Title", data=dataset3,order=dataset3['Book-Title'].value_counts().index[0:10])

# %%
plt.figure(figsize=(15,6))#8-10 rating author with maxmum count
sns.countplot(y="country", data=dataset1,order=dataset1['country'].value_counts().index[0:10])

# %%
#popular based 
def popularity_based(dataframe, n):
    if n >= 1 and n <= len(dataframe):
        data = pd.DataFrame(dataframe.groupby('ISBN')['Book-Rating'].count()).sort_values('Book-Rating', ascending=False).head(n)
        data1=pd.DataFrame(dataframe.groupby('ISBN')['Book-Rating'].unique())
        data2=pd.merge(data,data1, on='ISBN')
        result = pd.merge(data2, book, on='ISBN', left_index = False)
        return result
    return "Invalid number of books entered!!"

# %%
number = int(input("Enter number of books to recommend: "))
# Out:
# Enter number of books to recommend: 5

# %%
print("Top", number, "Popular books are: ")
popularity_based(dataset1,5)
# Out:
# Top 5 Popular books are:
#          ISBN  Book-Rating_x Book-Rating_y  \
# 0  0316666343  327            [10, 9]
# 1  0385504209  286            [9, 10]
# 2  059035342X  217            [10, 9]
# 3  0312195516  201            [10, 9]
# 4  0142001740  176            [9, 10]
#
#                                                          Book-Title  \
# 0  The Lovely Bones: A Novel
# 1  The Da Vinci Code
# 2  Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# 3  The Red Tent (Bestselling Backlist)
# 4  The Secret Life of Bees
#
#      Book-Author  Year-Of-Publication               Publisher  \
# 0  Alice Sebold   2002                 Little, Brown
# 1  Dan Brown      2003                 Doubleday
# 2  J. K. Rowling  1999                 Arthur A. Levine Books
# 3  Anita Diamant  1998                 Picador USA
# 4  Sue Monk Kidd  2003                 Penguin Books
#
#                                                     Image-URL-S  \
# 0  http://images.amazon.com/images/P/0316666343.01.THUMBZZZ.jpg
# 1  http://images.amazon.com/images/P/0385504209.01.THUMBZZZ.jpg
# 2  http://images.amazon.com/images/P/059035342X.01.THUMBZZZ.jpg
# 3  http://images.amazon.com/images/P/0312195516.01.THUMBZZZ.jpg
# 4  http://images.amazon.com/images/P/0142001740.01.THUMBZZZ.jpg
#
#                                                     Image-URL-M  \
# 0  http://images.amazon.com/images/P/0316666343.01.MZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0385504209.01.MZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/059035342X.01.MZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0312195516.01.MZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0142001740.01.MZZZZZZZ.jpg
#
#                                                     Image-URL-L
# 0  http://images.amazon.com/images/P/0316666343.01.LZZZZZZZ.jpg
# 1  http://images.amazon.com/images/P/0385504209.01.LZZZZZZZ.jpg
# 2  http://images.amazon.com/images/P/059035342X.01.LZZZZZZZ.jpg
# 3  http://images.amazon.com/images/P/0312195516.01.LZZZZZZZ.jpg
# 4  http://images.amazon.com/images/P/0142001740.01.LZZZZZZZ.jpg

# %%
popularity_threshold = 50
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
data = (dataset.groupby(by = ['Book-Title'])['Book-Rating'].count().reset_index().
        rename(columns = {'Book-Rating': 'Total-Rating'}))

result = pd.merge(data, dataset, on='Book-Title', left_index = False)
result = result[result['Total-Rating'] >= popularity_threshold]
result = result.reset_index(drop = True)

matrix = result.pivot_table(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating').fillna(0)
up_matrix = csr_matrix(matrix)

# %%
# for the recommdation of books we are taking target varible user-id as 171011 in which he as read --Harry Potter and the Prisoner of Azkaban (Book 3)
# recommeding the follwing books

# %%
bookName = input("Enter a book name: ")
model = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model.fit(up_matrix)

distances, indices = model.kneighbors(matrix.loc[bookName].values.reshape(1, -1), n_neighbors =10)
print("\nRecommended books:\n")
for i in range(0, len(distances.flatten())):
    if i > 0:
        print(matrix.index[indices.flatten()[i]])
# Out:
# Enter a book name: Harry Potter and the Prisoner of Azkaban (Book 3)
#
# Recommended books:
#
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Harry Potter and the Order of the Phoenix (Book 5)
# Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))
# The Fellowship of the Ring (The Lord of the Rings, Part 1)
# The Two Towers (The Lord of the Rings, Part 2)
# Charlie and the Chocolate Factory
# The Return of the King (The Lord of the Rings, Part 3)

# %%
data2=result[result['Book-Title']=="Harry Potter and the Prisoner of Azkaban (Book 3)"]#getting the details who read Harry Potter and the Prisoner of Azkaban (Book 3)

# %%
data3=result[result['Book-Title']=="Harry Potter and the Chamber of Secrets (Book 2)"]#getting the details who read Harry Potter and the Chamber of Secrets (Book 2)

# %%
x=set(data2["User-ID"].values)#contain the userid of those who read Harry Potter and the Prisoner of Azkaban (Book 3)
y=set(data3["User-ID"].values)#contain the userid of those who read Harry Potter and the Chamber of Secrets (Book 2)

# %%
similar_user=x & y # similar_user means both the user as read that book and given the same rating.
print(similar_user)
# Out:
# {171011, 232964, 249862, 137742, 30735, 240144, 170513, 220688, 23571, 20501, 92693, 21014, 12824, 208406, 179734, 251422, 249894, 33319, 238120, 100906, 75819, 145451, 253482, 15408, 91184, 129074, 119858, 267830, 201783, 88122, 273979, 120892, 136252, 153662, 182847, 240700, 69697, 249405, 59971, 227397, 31826, 158295, 271448, 259166, 225887, 265313, 234597, 249958, 168038, 87141, 6251, 122988, 150124, 156269, 168047, 141937, 111731, 173684, 189557, 14456, 212088, 264317, 195198, 52350, 9856, 169600, 196738, 254086, 160393, 170634, 193676, 274061, 51856, 81045, 226965, 103577, 88733, 248477, 111261, 68256, 31393, 36003, 212645, 131238, 256167, 116904, 231081, 192176, 228021, 53942, 198331, 104636, 232131, 55492, 147141, 276165, 4809, 77517, 169682, 108243, 184532, 77526, 104665, 78553, 177374, 177375, 164581, 211176, 2793, 169192, 88812, 22252, 246513, 15602, 138995, 170229, 102647, 254, 120579, 105221, 118533, 107784, 275210, 179978, 208141, 224525, 69389, 106768, 141070, 183061, 72990, 6431, 254241, 260897, 115490, 169249, 60707, 238889, 110890, 136491, 102702, 105263, 183088, 146230, 96054, 57661, 25919, 10560, 23872, 239423, 203075, 71490, 114498, 271176, 111947, 35148, 31053, 125774, 162639, 79186, 60244, 278356, 242006, 110934, 242007, 53590, 29526, 185176, 120155, 40795, 163676, 210792, 256874, 38762, 104812, 229741, 180591, 28016, 268657, 1903, 88435, 115572, 93047, 85367, 167800, 25981, 70014, 66942, 100227, 274308, 229768, 38281, 55178, 233867, 254859, 9613, 82831, 240528, 185233, 272786, 231827, 152468, 216466, 114581, 175003, 48539, 252829, 11676, 36256, 12194, 242083, 6563, 245666, 107431, 205735, 74665, 272810, 198055, 225191, 208815, 177073, 215986, 277427, 254899, 98741, 85426, 233911, 66487, 181176, 182202, 165308, 193469, 76223, 51647, 229313, 185282, 275401, 271306, 124876, 99277, 104399, 224209, 130554, 73681, 101851, 198621, 19422, 172512, 211426, 194534, 8681, 85993, 65004, 135149, 190448, 2033, 89074, 116210, 183284, 255477, 156150, 74743, 90616, 31226, 263163, 4092, 84479}

# %%
result[result["User-ID"]==171011].sort_values('Book-Rating', ascending=False).head(5)
# Out:
#                                                Book-Title  Total-Rating  \
# 89039  Harry Potter and the Chamber of Secrets (Book 2)    556
# 89407  Harry Potter and the Goblet of Fire (Book 4)        387
# 89753  Harry Potter and the Order of the Phoenix (Book 5)  347
# 90182  Harry Potter and the Prisoner of Azkaban (Book 3)   428
# 90481  Harry Potter and the Sorcerer's Stone (Book 1)      278
#
#              ISBN    Book-Author  Year-Of-Publication   Publisher  \
# 89039  0439064872  J. K. Rowling  2000                 Scholastic
# 89407  0439139597  J. K. Rowling  2000                 Scholastic
# 89753  043935806X  J. K. Rowling  2003                 Scholastic
# 90182  0439136369  J. K. Rowling  2001                 Scholastic
# 90481  043936213X  J. K. Rowling  2001                 Scholastic
#
#                                                         Image-URL-S  \
# 89039  http://images.amazon.com/images/P/0439064872.01.THUMBZZZ.jpg
# 89407  http://images.amazon.com/images/P/0439139597.01.THUMBZZZ.jpg
# 89753  http://images.amazon.com/images/P/043935806X.01.THUMBZZZ.jpg
# 90182  http://images.amazon.com/images/P/0439136369.01.THUMBZZZ.jpg
# 90481  http://images.amazon.com/images/P/043936213X.01.THUMBZZZ.jpg
#
#                                                         Image-URL-M  \
# 89039  http://images.amazon.com/images/P/0439064872.01.MZZZZZZZ.jpg
# 89407  http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg
# 89753  http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg
# 90182  http://images.amazon.com/images/P/0439136369.01.MZZZZZZZ.jpg
# 90481  http://images.amazon.com/images/P/043936213X.01.MZZZZZZZ.jpg
#
#                                                         Image-URL-L  User-ID  \
# 89039  http://images.amazon.com/images/P/0439064872.01.LZZZZZZZ.jpg  171011
# 89407  http://images.amazon.com/images/P/0439139597.01.LZZZZZZZ.jpg  171011
# 89753  http://images.amazon.com/images/P/043935806X.01.LZZZZZZZ.jpg  171011
# 90182  http://images.amazon.com/images/P/0439136369.01.LZZZZZZZ.jpg  171011
# 90481  http://images.amazon.com/images/P/043936213X.01.LZZZZZZZ.jpg  171011
#
#        Book-Rating  Age country
# 89039  10           13    usa
# 89407  10           13    usa
# 89753  10           13    usa
# 90182  10           13    usa
# 90481  10           13    usa

# %%
result[result["User-ID"]==232964].sort_values('Book-Rating', ascending=False).head(5)
# Out:
#                                                Book-Title  Total-Rating  \
# 90367   Harry Potter and the Sorcerer's Stone (Book 1)     278
# 115205  Life of Pi                                         665
# 88789   Harry Potter and the Chamber of Secrets (Book 2)   556
# 255804  The Talisman                                       227
# 90016   Harry Potter and the Prisoner of Azkaban (Book 3)  428
#
#               ISBN    Book-Author  Year-Of-Publication  \
# 90367   0590353403  J. K. Rowling  1998
# 115205  0151008116  Yann Martel    2002
# 88789   0439064864  J. K. Rowling  1999
# 255804  0425081818  Stephen King   1985
# 90016   0439136350  J. K. Rowling  1999
#
#                        Publisher  \
# 90367   Scholastic
# 115205  Harcourt
# 88789   Scholastic
# 255804  Berkley Publishing Group
# 90016   Scholastic
#
#                                                          Image-URL-S  \
# 90367   http://images.amazon.com/images/P/0590353403.01.THUMBZZZ.jpg
# 115205  http://images.amazon.com/images/P/0151008116.01.THUMBZZZ.jpg
# 88789   http://images.amazon.com/images/P/0439064864.01.THUMBZZZ.jpg
# 255804  http://images.amazon.com/images/P/0425081818.01.THUMBZZZ.jpg
# 90016   http://images.amazon.com/images/P/0439136350.01.THUMBZZZ.jpg
#
#                                                          Image-URL-M  \
# 90367   http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg
# 115205  http://images.amazon.com/images/P/0151008116.01.MZZZZZZZ.jpg
# 88789   http://images.amazon.com/images/P/0439064864.01.MZZZZZZZ.jpg
# 255804  http://images.amazon.com/images/P/0425081818.01.MZZZZZZZ.jpg
# 90016   http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-L  User-ID  \
# 90367   http://images.amazon.com/images/P/0590353403.01.LZZZZZZZ.jpg  232964
# 115205  http://images.amazon.com/images/P/0151008116.01.LZZZZZZZ.jpg  232964
# 88789   http://images.amazon.com/images/P/0439064864.01.LZZZZZZZ.jpg  232964
# 255804  http://images.amazon.com/images/P/0425081818.01.LZZZZZZZ.jpg  232964
# 90016   http://images.amazon.com/images/P/0439136350.01.LZZZZZZZ.jpg  232964
#
#         Book-Rating  Age country
# 90367   10           44    usa
# 115205  9            44    usa
# 88789   9            44    usa
# 255804  9            44    usa
# 90016   9            44    usa

# %%
result[result["User-ID"]==249862].sort_values('Book-Rating', ascending=False).head(5)
# Out:
#                                           Book-Title  Total-Rating  \
# 15787   All Around the Town                           187
# 96484   House Atreides (Dune: House Trilogy, Book 1)  69
# 226737  The Little Prince                             141
# 16506   All Quiet on the Western Front                78
# 140329  One for the Money (A Stephanie Plum Novel)    142
#
#               ISBN                Book-Author  Year-Of-Publication  \
# 15787   0671793489  Mary Higgins Clark         1993
# 96484   0553580272  Brian Herbert              2000
# 226737  0152023984  Antoine de Saint-ExupÃ©ry  2000
# 16506   0449213943  Erich Maria Remarque       1995
# 140329  0312990456  Janet Evanovich            2003
#
#                         Publisher  \
# 15787   Pocket Star
# 96484   Spectra Books
# 226737  Harcourt Children's Books
# 16506   Ballantine Books
# 140329  St. Martin's Paperbacks
#
#                                                          Image-URL-S  \
# 15787   http://images.amazon.com/images/P/0671793489.01.THUMBZZZ.jpg
# 96484   http://images.amazon.com/images/P/0553580272.01.THUMBZZZ.jpg
# 226737  http://images.amazon.com/images/P/0152023984.01.THUMBZZZ.jpg
# 16506   http://images.amazon.com/images/P/0449213943.01.THUMBZZZ.jpg
# 140329  http://images.amazon.com/images/P/0312990456.01.THUMBZZZ.jpg
#
#                                                          Image-URL-M  \
# 15787   http://images.amazon.com/images/P/0671793489.01.MZZZZZZZ.jpg
# 96484   http://images.amazon.com/images/P/0553580272.01.MZZZZZZZ.jpg
# 226737  http://images.amazon.com/images/P/0152023984.01.MZZZZZZZ.jpg
# 16506   http://images.amazon.com/images/P/0449213943.01.MZZZZZZZ.jpg
# 140329  http://images.amazon.com/images/P/0312990456.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-L  User-ID  \
# 15787   http://images.amazon.com/images/P/0671793489.01.LZZZZZZZ.jpg  249862
# 96484   http://images.amazon.com/images/P/0553580272.01.LZZZZZZZ.jpg  249862
# 226737  http://images.amazon.com/images/P/0152023984.01.LZZZZZZZ.jpg  249862
# 16506   http://images.amazon.com/images/P/0449213943.01.LZZZZZZZ.jpg  249862
# 140329  http://images.amazon.com/images/P/0312990456.01.LZZZZZZZ.jpg  249862
#
#         Book-Rating  Age country
# 15787   10           30    usa
# 96484   10           30    usa
# 226737  10           30    usa
# 16506   10           30    usa
# 140329  10           30    usa

# %%
result[result["User-ID"]==137742].sort_values('Book-Rating', ascending=False).head(5)
# Out:
#                                                         Book-Title  \
# 16107   All I Need Is You
# 90139   Harry Potter and the Prisoner of Azkaban (Book 3)
# 259088  The Two Towers (The Lord of the Rings, Part 2)
# 245844  The Return of the King (The Lord of the Rings, Part 3)
# 209427  The Fellowship of the Ring (The Lord of the Rings, Part 1)
#
#         Total-Rating        ISBN       Book-Author  Year-Of-Publication  \
# 16107   60            0380762609  Johanna Lindsey   1998
# 90139   428           0439136350  J. K. Rowling     1999
# 259088  260           0618129081  J. R. R. Tolkien  2001
# 245844  211           0618129111  J. R. R. Tolkien  2001
# 209427  368           0618129030  J. R. R. Tolkien  2001
#
#                        Publisher  \
# 16107   Avon
# 90139   Scholastic
# 259088  Houghton Mifflin Company
# 245844  Houghton Mifflin Company
# 209427  Houghton Mifflin Company
#
#                                                          Image-URL-S  \
# 16107   http://images.amazon.com/images/P/0380762609.01.THUMBZZZ.jpg
# 90139   http://images.amazon.com/images/P/0439136350.01.THUMBZZZ.jpg
# 259088  http://images.amazon.com/images/P/0618129081.01.THUMBZZZ.jpg
# 245844  http://images.amazon.com/images/P/0618129111.01.THUMBZZZ.jpg
# 209427  http://images.amazon.com/images/P/0618129030.01.THUMBZZZ.jpg
#
#                                                          Image-URL-M  \
# 16107   http://images.amazon.com/images/P/0380762609.01.MZZZZZZZ.jpg
# 90139   http://images.amazon.com/images/P/0439136350.01.MZZZZZZZ.jpg
# 259088  http://images.amazon.com/images/P/0618129081.01.MZZZZZZZ.jpg
# 245844  http://images.amazon.com/images/P/0618129111.01.MZZZZZZZ.jpg
# 209427  http://images.amazon.com/images/P/0618129030.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-L  User-ID  \
# 16107   http://images.amazon.com/images/P/0380762609.01.LZZZZZZZ.jpg  137742
# 90139   http://images.amazon.com/images/P/0439136350.01.LZZZZZZZ.jpg  137742
# 259088  http://images.amazon.com/images/P/0618129081.01.LZZZZZZZ.jpg  137742
# 245844  http://images.amazon.com/images/P/0618129111.01.LZZZZZZZ.jpg  137742
# 209427  http://images.amazon.com/images/P/0618129030.01.LZZZZZZZ.jpg  137742
#
#         Book-Rating  Age              country
# 16107   10           24    dominican republic
# 90139   10           24    dominican republic
# 259088  10           24    dominican republic
# 245844  10           24    dominican republic
# 209427  10           24    dominican republic

# %%
result[result["User-ID"]==30735].sort_values('Book-Rating', ascending=False).head(5)
# Out:
#                                                     Book-Title  Total-Rating  \
# 5201    A Is for Alibi (Kinsey Millhone Mysteries (Paperback))  285
# 101491  Imajica                                                 57
# 89210   Harry Potter and the Goblet of Fire (Book 4)            387
# 89583   Harry Potter and the Order of the Phoenix (Book 5)      347
# 90330   Harry Potter and the Sorcerer's Stone (Book 1)          278
#
#               ISBN    Book-Author  Year-Of-Publication    Publisher  \
# 5201    0553279912  SUE GRAFTON    1987                 Bantam
# 101491  0061099643  Clive Barker   1992                 HarperTorch
# 89210   0439139597  J. K. Rowling  2000                 Scholastic
# 89583   043935806X  J. K. Rowling  2003                 Scholastic
# 90330   0590353403  J. K. Rowling  1998                 Scholastic
#
#                                                          Image-URL-S  \
# 5201    http://images.amazon.com/images/P/0553279912.01.THUMBZZZ.jpg
# 101491  http://images.amazon.com/images/P/0061099643.01.THUMBZZZ.jpg
# 89210   http://images.amazon.com/images/P/0439139597.01.THUMBZZZ.jpg
# 89583   http://images.amazon.com/images/P/043935806X.01.THUMBZZZ.jpg
# 90330   http://images.amazon.com/images/P/0590353403.01.THUMBZZZ.jpg
#
#                                                          Image-URL-M  \
# 5201    http://images.amazon.com/images/P/0553279912.01.MZZZZZZZ.jpg
# 101491  http://images.amazon.com/images/P/0061099643.01.MZZZZZZZ.jpg
# 89210   http://images.amazon.com/images/P/0439139597.01.MZZZZZZZ.jpg
# 89583   http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg
# 90330   http://images.amazon.com/images/P/0590353403.01.MZZZZZZZ.jpg
#
#                                                          Image-URL-L  User-ID  \
# 5201    http://images.amazon.com/images/P/0553279912.01.LZZZZZZZ.jpg  30735
# 101491  http://images.amazon.com/images/P/0061099643.01.LZZZZZZZ.jpg  30735
# 89210   http://images.amazon.com/images/P/0439139597.01.LZZZZZZZ.jpg  30735
# 89583   http://images.amazon.com/images/P/043935806X.01.LZZZZZZZ.jpg  30735
# 90330   http://images.amazon.com/images/P/0590353403.01.LZZZZZZZ.jpg  30735
#
#         Book-Rating  Age country
# 5201    10           30    usa
# 101491  10           30    usa
# 89210   10           30    usa
# 89583   10           30    usa
# 90330   10           30    usa

# %%
# i have taken similiar user-id (read the book and given the good rating)(9602,87555,249862,9227,47116) the following are the books

# %%
#top book read by user
list=("Harry Potter and the Chamber of Secrets (Book 2)","Harry Potter and the Goblet of Fire (Book 4)","Harry Potter and the Order of the Phoenix (Book 5)","Harry Potter and the Prisoner of Azkaban (Book 3)","Harry Potter and the Sorcerer's Stone (Book 1)","Harry Potter and the Sorcerer's Stone (Book 1)","Life of Pi","Harry Potter and the Chamber of Secrets (Book 2)","The Talisman","Harry Potter and the Prisoner of Azkaban (Book 3)","All Around the Town","House Atreides (Dune: House Trilogy, Book 1)","The Little Prince","All Quiet on the Western Front","One for the Money (A Stephanie Plum Novel)","All I Need Is You","Harry Potter and the Prisoner of Azkaban (Book 3)","The Two Towers (The Lord of the Rings, Part 2)","The Return of the King (The Lord of the Rings, Part 3)","The Fellowship of the Ring (The Lord of the Rings, Part 1)","A Is for Alibi (Kinsey Millhone Mysteries (Paperback))","Imajica","Harry Potter and the Goblet of Fire (Book 4)","Harry Potter and the Order of the Phoenix (Book 5)","Harry Potter and the Sorcerer's Stone (Book 1)")

# %%
list#top25 books
# Out:
# ('Harry Potter and the Chamber of Secrets (Book 2)',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  'Harry Potter and the Order of the Phoenix (Book 5)',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  "Harry Potter and the Sorcerer's Stone (Book 1)",
#  'Life of Pi',
#  'Harry Potter and the Chamber of Secrets (Book 2)',
#  'The Talisman',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  'All Around the Town',
#  'House Atreides (Dune: House Trilogy, Book 1)',
#  'The Little Prince',
#  'All Quiet on the Western Front',
#  'One for the Money (A Stephanie Plum Novel)',
#  'All I Need Is You',
#  'Harry Potter and the Prisoner of Azkaban (Book 3)',
#  'The Two Towers (The Lord of the Rings, Part 2)',
#  'The Return of the King (The Lord of the Rings, Part 3)',
#  'The Fellowship of the Ring (The Lord of the Rings, Part 1)',
#  'A Is for Alibi (Kinsey Millhone Mysteries (Paperback))',
#  'Imajica',
#  'Harry Potter and the Goblet of Fire (Book 4)',
#  'Harry Potter and the Order of the Phoenix (Book 5)',
#  "Harry Potter and the Sorcerer's Stone (Book 1)")

# %%
import pickle
pickle.dump(matrix,open("books.pk1","wb"))
pickle.dump(model,open("model.pk1","wb"))
pickle.dump(result,open("result.pk1","wb"))
